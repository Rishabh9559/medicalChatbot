# %%
import pandas as pd

# %%
df = pd.read_csv("hf://datasets/keivalya/MedQuad-MedicalQnADataset/medDataset_processed.csv")

df.to_csv("medDataset.csv", index=False)

# %%
data=pd.read_csv("medDataset.csv")

data
# Out:
#                  qtype                                           Question  \
# 0       susceptibility  Who is at risk for Lymphocytic Choriomeningiti...
# 1             symptoms  What are the symptoms of Lymphocytic Choriomen...
# 2       susceptibility  Who is at risk for Lymphocytic Choriomeningiti...
# 3      exams and tests  How to diagnose Lymphocytic Choriomeningitis (...
# 4            treatment  What are the treatments for Lymphocytic Chorio...
# ...                ...                                                ...
# 16402         symptoms  What are the symptoms of Familial visceral myo...
# 16403      information              What is (are) Pseudopelade of Brocq ?
# 16404         symptoms   What are the symptoms of Pseudopelade of Brocq ?
# 16405        treatment  What are the treatments for Pseudopelade of Br...
# 16406      information  What is (are) Desmoplastic small round cell tu...
#
#                                                   Answer
# ...

# %%
print(data.loc[0, 'Answer'])
# Out:
# LCMV infections can occur after exposure to fresh urine, droppings, saliva, or nesting materials from infected rodents.  Transmission may also occur when these materials are directly introduced into broken skin, the nose, the eyes, or the mouth, or presumably, via the bite of an infected rodent. Person-to-person transmission has not been reported, with the exception of vertical transmission from infected mother to fetus, and rarely, through organ transplantation.

# %%
data=pd.read_csv("medDataset.csv")
data
# Out:
#                  qtype                                           Question  \
# 0       susceptibility  Who is at risk for Lymphocytic Choriomeningiti...
# 1             symptoms  What are the symptoms of Lymphocytic Choriomen...
# 2       susceptibility  Who is at risk for Lymphocytic Choriomeningiti...
# 3      exams and tests  How to diagnose Lymphocytic Choriomeningitis (...
# 4            treatment  What are the treatments for Lymphocytic Chorio...
# ...                ...                                                ...
# 16402         symptoms  What are the symptoms of Familial visceral myo...
# 16403      information              What is (are) Pseudopelade of Brocq ?
# 16404         symptoms   What are the symptoms of Pseudopelade of Brocq ?
# 16405        treatment  What are the treatments for Pseudopelade of Br...
# 16406      information  What is (are) Desmoplastic small round cell tu...
#
#                                                   Answer
# ...

# %%
new_data = pd.DataFrame({
    'chunk': "Question: " + data['Question'] + "  " + " Answer: " + data['Answer'],
})

new_data.insert(1,'index', range(1, len(new_data) + 1))

new_data.to_csv("newData.csv")

# %%
data=pd.read_csv('newData.csv')
data
# Out:
#        Unnamed: 0                                              chunk  index
# 0               0  Question: Who is at risk for Lymphocytic Chori...      1
# 1               1  Question: What are the symptoms of Lymphocytic...      2
# 2               2  Question: Who is at risk for Lymphocytic Chori...      3
# 3               3  Question: How to diagnose Lymphocytic Choriome...      4
# 4               4  Question: What are the treatments for Lymphocy...      5
# ...           ...                                                ...    ...
# 16402       16402  Question: What are the symptoms of Familial vi...  16403
# 16403       16403  Question: What is (are) Pseudopelade of Brocq ...  16404
# 16404       16404  Question: What are the symptoms of Pseudopelad...  16405
# 16405       16405  Question: What are the treatments for Pseudope...  16406
# 16406       16406  Question: What is (are) Desmoplastic small rou...  16407
#
# [16407 rows x 3 columns]

# %%
data[['index', 'chunk']].to_json('data.json', orient='records', lines=True)
